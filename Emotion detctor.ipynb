# %%
from transformers import pipeline
classifier = pipeline("zero-shot-classification")
labels=["Happy","Sad","Angry","Fear","Surprise"]

def emotion_detector(text):
  result=classifier(text,labels)
  top_emotion= result["labels"][0]
  confidence=round(result["scores"][0]*100,2)
  return top_emotion,confidence
import gradio as gr

interface = gr.Interface(fn=emotion_detector,
                         inputs="text",
                         outputs=["text","text"],
                         title="Emotion Detection from Text",
                         description="Enter a sentence to detect the underlying emotion")

interface.launch()
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://a9bafb93f304603473.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a9bafb93f304603473.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
